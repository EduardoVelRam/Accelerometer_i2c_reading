# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoVelRam/Accelerometer_i2c_reading/blob/main/Activity1105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Descripción de Script en Google Colab

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets
from sklearn.model_selection import train_test_split
